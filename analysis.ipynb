# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
#get the dataset list of seaborn
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 #get the dataset list of seaborn
# ----> 2 sns.get_dataset_names()
#
# File c:\Users\91700\miniconda3\Lib\site-packages\seaborn\utils.py:499, in get_dataset_names()
#     493 def get_dataset_names():
#     494     """Report available example datasets, useful for reporting issues.
#     495
#     496     Requires an internet connection.
#     497
#     498     """
# --> 499     with urlopen(DATASET_NAMES_URL) as resp:
#     500         txt = resp.read()
#     502     dataset_names = [name.strip() for name in txt.decode().split("\n")]
#
# File c:\Users\91700\miniconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# ...

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 786         1       3  female  18.0      0      0  7.4958        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 786  woman       False  NaN  Southampton   yes   True
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.sample(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 20          0       2  male  35.0      0      0  26.0000        S  Second
# 421         0       3  male  21.0      0      0   7.7333        Q   Third
# 477         0       3  male  29.0      1      0   7.0458        S   Third
# 762         1       3  male  20.0      0      0   7.2292        C   Third
# 59          0       3  male  11.0      5      2  46.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 20     man        True  NaN  Southampton    no   True
# 421    man        True  NaN   Queenstown    no   True
# 477    man        True  NaN  Southampton    no  False
# 762    man        True  NaN    Cherbourg   yes   True
# 59   child       False  NaN  Southampton    no  False

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.describe(include="object")
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# selecting data in pandas
#
# -rows
#  - iloc - index based location
#  - loc- label based location
# - columns
#
# - single column selstion
#
# - multiple column selection
#
# - selection by datatype

# %%
#selecting 100th index posotioned row from the dataset 
df.iloc[100]
# Out:
# survived                 0
# pclass                   3
# sex                 female
# age                   28.0
# sibsp                    0
# parch                    0
# fare                7.8958
# embarked                 S
# class                Third
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 100, dtype: object

# %%
df.iloc[[1,59,45,76]]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 59         0       3    male  11.0      5      2  46.9000        S  Third
# 45         0       3    male   NaN      0      0   8.0500        S  Third
# 76         0       3    male   NaN      0      0   7.8958        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 59  child       False  NaN  Southampton    no  False
# 45    man        True  NaN  Southampton    no   True
# 76    man        True  NaN  Southampton    no   True

# %%
df.iloc[[1,10,20],[2,3,4]]
# Out:
#        sex   age  sibsp
# 1   female  38.0      1
# 10  female   4.0      1
# 20    male  35.0      0

# %%
df.iloc[50:61]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 50         0       3    male   7.0      4      1  39.6875        S   Third
# 51         0       3    male  21.0      0      0   7.8000        S   Third
# 52         1       1  female  49.0      1      0  76.7292        C   First
# 53         1       2  female  29.0      1      0  26.0000        S  Second
# 54         0       1    male  65.0      0      1  61.9792        C   First
# 55         1       1    male   NaN      0      0  35.5000        S   First
# 56         1       2  female  21.0      0      0  10.5000        S  Second
# 57         0       3    male  28.5      0      0   7.2292        C   Third
# 58         1       2  female   5.0      1      2  27.7500        S  Second
# 59         0       3    male  11.0      5      2  46.9000        S   Third
# 60         0       3    male  22.0      0      0   7.2292        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Single dictionary selection
#
# dictionary like selection
#  - dataframe['column-name]
#
#  object like selection
#  - dataframe.column-name
#
#  Multiple column Selection
#
#
#  dictionary like selection
#
#  - dataframe[[list-of-columns-name]]

# %%
df['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df.embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %% [markdown]
# Manipulating and Cleaning Data
#  - removing column n rows
#  - remaing columns
#  - adding coumns
#  - changing datatypes
#  - handling mussing values
#  - dropping missing values
#  - using apply() method

# %%
colto_drop = ['alive,'pclass','who']
df = df.drop(cs_olumns=cols_to_drop)
df
# Out:
#   Cell In[63], line 1
#     cols_to_drop = ['alive,'pclass','who']
#                                         ^
# SyntaxError: unterminated string literal (detected at line 1)
